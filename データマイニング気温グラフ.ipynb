# %%
import numpy
import pandas
import datetime

data = pandas.read_csv('res.txt',index_col='date', parse_dates=['date'],header=3)

# %matplotlib inline
start = data.index.searchsorted(datetime.datetime(2008, 1, 1))
end = data.index.searchsorted(datetime.datetime(2009, 1, 1))
data[start:end].plot()

start = data.index.searchsorted(datetime.datetime(2008, 1, 1))
end = data.index.searchsorted(datetime.datetime(2009, 1, 1))
data[start:end].plot()
